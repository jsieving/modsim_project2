# %% [markdown]
# # Modeling and Simulation in Python
#
# Chapter 5: Design
#
# Copyright 2017 Allen Downey
#
# License: [Creative Commons Attribution 4.0 International](https://creativecommons.org/licenses/by/4.0)

# %%
# %matplotlib inline


#asdfasdfasdfa

from modsim import *

# %% [markdown]
# Quarantine would be like an additional phase between infection and recovery. Perhaps it would take students 2 days to realize they were ill and get quarantined, and 2 more days to recover. You now have 4 stocks, S, I, Q, and R, and 3 flow rates.

# %%
def make_system(ct, inc, pk, p1, p2):

    init = State(S=89, I=1, P=0, R=0, A=0)
    init /= sum(init)

    t0 = 0
    t_end = 7 * 14

    return System(init=init, t0=t0, t_end=t_end,
                  ct = ct, inc = inc, pk = pk, p1 = p1, p2 = p2, absent=0)

# %%
ct = 1/2
inc = 1/5
pk = 1/2
p1 = .80
p2 = .20

system = make_system(ct, inc, pk, p1, p2)

# %%
def update(state, system):
    unpack(system)
    s, i, p, r, a= state
    
    infected = ct * (i*p1 + p*p2) * s
    peak = inc * i
    recovered = pk * p
    absent = i*(1-p1)+p*(1-p2)
    
    s -= infected
    i += infected - peak
    p += peak - recovered
    r += recovered
    a += absent
    return State(S=s, I=i, P=p, R=r, A=a)

# %%
def run_simulation(system, update_func):
   
    S = TimeSeries()
    I = TimeSeries()
    P = TimeSeries()
    R = TimeSeries()
    A = TimeSeries()

    state = system.init
    t0 = system.t0
    S[t0], I[t0], P[t0], R[t0], A[t0] = state
    
    for t in linrange(system.t0, system.t_end):
        state = update_func(state, system)
        S[t+1], I[t+1], P[t+1], R[t+1], A[t+1]= state
    
    system.S = S
    system.I = I
    system.P = P
    system.R = R
    system.A = A

# %%
def run_simulation2(system, update_func):
    frame = DataFrame(columns=system.init.index)
    frame.loc[system.t0] = system.init
    
    for t in linrange(system.t0, system.t_end):
        frame.loc[t+1] = update_func(frame.loc[t], system)
    
    system.results = frame
    
    return frame

# %%
def plot_results(S, I, P, R, A):
    plot(S, '--', color='blue', label='Susceptible')
    plot(I, '-', color='red', label='Infected')
    plot(P, '.', color = 'yellow', label='Peak')
    plot(R, ':', color='green', label='Recovered')
    plot(A, '*', color='Purple', label='Absences')
    legend(loc ='best')
    decorate(xlabel='Time (days)',
             ylabel='Fraction of population')

# %%
run_simulation2(system, update)
# Out:
#            S         I         P         R         A
# 0   0.988889  0.011111  0.000000  0.000000  0.000000
# 1   0.984494  0.013284  0.002222  0.000000  0.002222
# 2   0.979044  0.016077  0.003768  0.001111  0.006657
# 3   0.972379  0.019527  0.005099  0.002995  0.012887
# 4   0.964288  0.023712  0.006455  0.005545  0.020871
# 5   0.954520  0.028738  0.007970  0.008772  0.030778
# 6   0.942786  0.034724  0.009733  0.012757  0.042901
# 7   0.928774  0.041792  0.011811  0.017624  0.057632
# 8   0.912151  0.050056  0.014264  0.023529  0.075439
# 9   0.892586  0.059610  0.017143  0.030661  0.096862
# 10  0.869773  0.070500  0.020493  0.039233  0.122498
# 11  0.843463  0.082711  0.024347  0.049479  0.152993
# 12  0.813504  0.096127  0.028716  0.061653  0.189013
# 13  0.779888  0.110518  0.033583  0.076011  0.231211
# 14  0.742792  0.125510  0.038895  0.092802  0.280181
# 15  0.702612  0.140588  0.044550  0.112250  0.336399
# 16  0.659970  0.155113  0.050393  0.134525  0.400156
# 17  0.615697  0.168364  0.056219  0.159721  0.471493
# 18  0.570771  0.179617  0.061782  0.187830  0.550141
# 19  0.526237  0.188228  0.066814  0.218721  0.635490
# 20  0.483100  0.193719  0.071053  0.252128  0.726587
# 21  0.442233  0.195842  0.074270  0.287655  0.822173
# 22  0.404305  0.194601  0.076304  0.324790  0.920757
# 23  0.369749  0.190237  0.077072  0.362942  1.020720
# 24  0.338763  0.183176  0.076583  0.401478  1.120425
# 25  0.311348  0.173956  0.074927  0.439769  1.218327
# 26  0.287350  0.163162  0.072255  0.477233  1.313060
# 27  0.266520  0.151360  0.068760  0.513360  1.403496
# 28  0.248552  0.139057  0.064652  0.547740  1.488776
# 29  0.233120  0.126677  0.060137  0.580066  1.568309
# ..       ...       ...       ...       ...       ...
# 70  0.141482  0.000443  0.000243  0.857832  2.230607
# 71  0.141453  0.000383  0.000210  0.857954  2.230890
# 72  0.141429  0.000331  0.000182  0.858059  2.231135
# 73  0.141407  0.000286  0.000157  0.858150  2.231346
# 74  0.141389  0.000247  0.000136  0.858228  2.231529
# 75  0.141373  0.000214  0.000117  0.858296  2.231687
# 76  0.141359  0.000185  0.000101  0.858355  2.231824
# 77  0.141347  0.000160  0.000088  0.858405  2.231942
# 78  0.141337  0.000138  0.000076  0.858449  2.232044
# 79  0.141328  0.000119  0.000065  0.858487  2.232132
# 80  0.141321  0.000103  0.000057  0.858520  2.232208
# 81  0.141314  0.000089  0.000049  0.858548  2.232274
# 82  0.141308  0.000077  0.000042  0.858573  2.232331
# 83  0.141303  0.000067  0.000037  0.858594  2.232380
# 84  0.141299  0.000057  0.000032  0.858612  2.232423
# 85  0.141295  0.000050  0.000027  0.858628  2.232459
# 86  0.141292  0.000043  0.000024  0.858641  2.232491
# 87  0.141289  0.000037  0.000020  0.858653  2.232518
# 88  0.141287  0.000032  0.000018  0.858663  2.232542
# 89  0.141285  0.000028  0.000015  0.858672  2.232563
# 90  0.141283  0.000024  0.000013  0.858680  2.232580
# 91  0.141282  0.000021  0.000011  0.858686  2.232596
# 92  0.141280  0.000018  0.000010  0.858692  2.232609
# 93  0.141279  0.000015  0.000008  0.858697  2.232620
# 94  0.141278  0.000013  0.000007  0.858701  2.232630
# 95  0.141277  0.000012  0.000006  0.858705  2.232639
# 96  0.141277  0.000010  0.000005  0.858708  2.232646
# 97  0.141276  0.000009  0.000005  0.858711  2.232653
# 98  0.141275  0.000007  0.000004  0.858713  2.232658
# 99  0.141275  0.000006  0.000004  0.858715  2.232663
#
# [100 rows x 5 columns]

# %%
#plot_results(system.S, system.I, system.P, system.R, system.A)

# %%
frame = system.results
plot_results(frame.S, frame.I, frame.P, frame.R, frame.A)
frame.A[system.t_end]
# Out:
# 2.2326581298668682

# %%
def run_simulation2(system, update_func):
    frame = DataFrame(columns=system.init.index)
    frame.loc[system.t0] = system.init
    
    for t in linrange(system.t0, system.t_end):
        frame.loc[t+1] = update_func(frame.loc[t], system)
    
    system.results = frame
    
    return frame

# %%
def plot_sweep(var, S, I, P, R, A):
    plot(S, '--', color='blue', label='Susceptible')
    plot(I, '-', color='red', label='Infected')
    plot(P, '.', color = 'yellow', label='Peak')
    plot(R, ':', color='green', label='Recovered')
    plot(A, '*', color='Purple', label='Absences')
    legend(loc ='best')
    decorate(xlabel=var,
             ylabel='Fraction of population')

# %%
def sweep_p1(system):
    p_array = linspace(.1, .95, 15)
    
    p_sweep_frame = DataFrame(columns=system.init.index)
    
    for p in p_array:
        system = make_system(ct, inc, pk, p, p2)
        
        frame = run_simulation2(system, update)
        p_sweep_frame.loc[p] = frame.loc[system.t_end]
        
    return p_sweep_frame
        
def sweep_p2(system):
    p_array = linspace(.05, .25, 15)
    
    p_sweep_frame = DataFrame(columns=system.init.index)
    
    for p2 in p_array:
        system = make_system(ct, inc, pk, p1, p2)
        
        frame = run_simulation2(system, update)
        p_sweep_frame.loc[p2] = frame.loc[system.t_end]
        
    return p_sweep_frame

# %%
sweep_frame = sweep_p1(system)

plot_sweep('p1', sweep_frame.S, sweep_frame.I, sweep_frame.P, sweep_frame.R, sweep_frame.A)
savefig('Sweep_p1.pdf')
Avals = sweep_frame.A
print(Avals)
# Out:
# Saving figure to file Sweep_p1.pdf
# 0.100000    1.326265
# 0.160714    1.972205
# 0.221429    2.358805
# 0.282143    2.516283
# 0.342857    2.533570
# 0.403571    2.461716
# 0.464286    2.328495
# 0.525000    2.151103
# 0.585714    1.941215
# 0.646429    1.707143
# 0.707143    1.454945
# 0.767857    1.189104
# 0.828571    0.912977
# 0.889286    0.629093
# 0.950000    0.339376
# Name: A, dtype: float64

# %%
sweep_frame = sweep_p2(system)

plot_sweep('p2', sweep_frame.S, sweep_frame.I, sweep_frame.P, sweep_frame.R, sweep_frame.A)
Avals = sweep_frame.A
print(Avals)
# Out:
# 0.050000    1.929312
# 0.064286    1.907911
# 0.078571    1.886310
# 0.092857    1.864515
# 0.107143    1.842531
# 0.121429    1.820363
# 0.135714    1.798016
# 0.150000    1.775495
# 0.164286    1.752805
# 0.178571    1.729950
# 0.192857    1.706934
# 0.207143    1.683762
# 0.221429    1.660439
# 0.235714    1.636967
# 0.250000    1.613352
# Name: A, dtype: float64
